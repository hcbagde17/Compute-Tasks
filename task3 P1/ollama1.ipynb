# %%
import ollama

# %%
client = ollama.Client()
model = "tinyllama"
while True:
    prompt = input("Enter your prompt (or type 'q' to quit): ")
    if prompt.lower() == 'q':
        break
    response = client.generate(model=model, prompt=prompt)
    print(response.response)
# Out:
# Hi! I'm doing great, thank you. How about you?
#
# I am also fine! Doing some work and enjoying the weekend so far. Hope you're having a good one too!
# hello there! I'm doing fine, thank you for asking. How about yourself?
