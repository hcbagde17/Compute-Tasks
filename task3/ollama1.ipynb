# %%
import ollama

# %%
client = ollama.Client()
model = "tinyllama"
while True:
    prompt = input("Enter your prompt (or type 'q' to quit): ")
    if prompt.lower() == 'q':
        break
    response = client.generate(model=model, prompt=prompt)
    print(response.response)
# Out:
# Gravity is the attraction between two objects in motion, or more precisely, their attractive force due to the curvature of spacetime. Gravity is a fundamental force that exists between objects in the universe, ranging from tiny particles like protons and atoms, through galaxies and stars, to entire planets and moons.
#
# The concept of gravity is based on the idea that masses and objects are affected by each other's accelerations over relatively short distances. The principle behind gravity, called Newtonian gravity, was first proposed by Isaac Newton in the 17th century and has since been confirmed through a range of experiments and observations.
#
# In addition to classical Newtonian gravity, there is also modern general relativity, which includes additional effects due to the curvature of spacetime. These include the presence of gravitational waves produced by the mergers of neutron stars or black holes and the effect on the orbits of massive objects in the universe.
#
# Gravity is an essential force that underlies the behavior of matter and can be observed through a variety of physical phenomena, including the orbiting of celestial bodies, the movement of planets, and the weight of a falling object. It also plays a role in many scientific fields, including physics, astronomy, and astrophysics.
#
# Despite its importance, gravity remains one of the most elusive forces in the universe. Its nature and origin are still mysteries that are being researched by scientists and explored through various experiments and observations.
